# %%
import pandas as pd

# %%
json = "https://data.cdc.gov/resource/n8mc-b4w4.json?$limit=10000000"
df = pd.read_json(json)
df.head(10)
# Out:
#   case_month res_state state_fips_code   res_county county_fips_code  \
# 0    2022-06        CA              06  LOS ANGELES            06037
# 1    2020-12        TX              48           NA               NA
# 2    2021-12        CA              06  LOS ANGELES            06037
# 3    2021-11        NE              31           NA               NA
# 4    2020-09        TX              48           NA               NA
# 5    2022-06        CA              06  LOS ANGELES            06037
# 6    2021-12        CA              06  LOS ANGELES            06037
# 7    2021-11        NE              31           NA               NA
# 8    2022-06        CA              06  LOS ANGELES            06037
# 9    2020-12        TX              48           NA               NA
#
#         age_group     sex   race            ethnicity  process exposure_yn  \
# 0  18 to 49 years  Female  Asian  Non-Hispanic/Latino  Missing     Missing
# 1       65+ years      NA     NA                   NA  Missing     Missing
# 2  18 to 49 years  Female  Black  Non-Hispanic/Latino  Missing     Missing
# 3  18 to 49 years  Female  White  Non-Hispanic/Latino  Missing     Missing
# 4    0 - 17 years    Male  White      Hispanic/Latino  Missing     Missing
# 5  18 to 49 years  Female  Asian  Non-Hispanic/Latino  Missing     Missing
# 6  18 to 49 years  Female  Black  Non-Hispanic/Latino  Missing     Missing
# 7  18 to 49 years  Female  White  Non-Hispanic/Latino  Missing     Missing
# 8  18 to 49 years  Female  Asian  Non-Hispanic/Latino  Missing     Missing
# 9       65+ years      NA     NA                   NA  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 1  Laboratory-confirmed case    Symptomatic      Yes  Missing      Yes
# 2  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 3  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 5  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 6  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 7  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 8  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 9  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn  case_onset_interval  case_positive_specimen
# 0                      Yes                  NaN                     NaN
# 1                      NaN                 -1.0                     NaN
# 2                      NaN                  NaN                     NaN
# 3                      NaN                  0.0                     NaN
# 4                      NaN                 -1.0                     NaN
# 5                      NaN                  0.0                     NaN
# 6                      NaN                  0.0                     NaN
# 7                      NaN                  0.0                     NaN
# 8                      NaN                  NaN                     NaN
# 9                      NaN                  NaN                     NaN

# %%
df = df.drop(['state_fips_code', 'county_fips_code', 'ethnicity', 'process', 'exposure_yn', 'case_onset_interval', 'case_positive_specimen', 'exposure_yn', 'case_onset_interval', 'case_positive_specimen'], axis=1)
df.head(10)
# Out:
#   case_month res_state   res_county       age_group     sex   race  \
# 0    2022-06        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 1    2020-12        TX           NA       65+ years      NA     NA
# 2    2021-12        CA  LOS ANGELES  18 to 49 years  Female  Black
# 3    2021-11        NE           NA  18 to 49 years  Female  White
# 4    2020-09        TX           NA    0 - 17 years    Male  White
# 5    2022-06        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 6    2021-12        CA  LOS ANGELES  18 to 49 years  Female  Black
# 7    2021-11        NE           NA  18 to 49 years  Female  White
# 8    2022-06        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 9    2020-12        TX           NA       65+ years      NA     NA
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 1  Laboratory-confirmed case    Symptomatic      Yes  Missing      Yes
# 2  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 3  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 5  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 6  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 7  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 8  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 9  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 0                      Yes
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN

# %%
# NA's are populating in case_month with latest JSON query?
df = df[df['case_month'] != 'NA']
df["case_month"].unique()
# Out:
# array(['2022-06', '2020-12', '2021-12', '2021-11', '2020-09', '2022-04',
#        '2022-01', '2022-02', '2023-03', '2021-01', '2021-09', '2023-01',
#        '2020-10', '2022-10', '2020-11', '2022-07', '2022-08', '2020-04',
#        '2020-06', '2021-02', '2022-09', '2022-12', '2022-11', '2021-10',
#        '2020-07', '2023-02', '2021-08', '2022-05', '2020-05', '2021-06',
#        '2020-03', '2022-03', '2021-04', '2021-05', '2021-03', '2021-07',
#        '2020-08', '2020-01', '2020-02'], dtype=object)

# %%
df["case_month"] = pd.to_datetime(df["case_month"], format='%Y-%m')
df.dtypes
# Out:
# case_month                  datetime64[ns]
# res_state                           object
# res_county                          object
# age_group                           object
# sex                                 object
# race                                object
# current_status                      object
# symptom_status                      object
# hosp_yn                             object
# icu_yn                              object
# death_yn                            object
# underlying_conditions_yn            object
# dtype: object

# %%
len(df)
# Out:
# 9999975

# %%
# What rows needed to be dropped through dropna()
print(f"Age Group column contains: {df['age_group'].unique()}")
print(f"Sex column contains: {df['sex'].unique()}")
print(f"Race column contains: {df['race'].unique()}")
# Out:
# Age Group column contains: ['18 to 49 years' '65+ years' '0 - 17 years' 'Missing' 'NA'
#  '50 to 64 years']
# Sex column contains: ['Female' 'NA' 'Male' 'Other' 'Unknown' 'Missing']
# Race column contains: ['Asian' 'NA' 'Black' 'White' 'Unknown' 'American Indian/Alaska Native'
#  'Missing' 'Native Hawaiian/Other Pacific Islander' 'Multiple/Other']

# %%
df.head(10)
# Out:
#   case_month res_state   res_county       age_group     sex   race  \
# 0 2022-06-01        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 1 2020-12-01        TX           NA       65+ years      NA     NA
# 2 2021-12-01        CA  LOS ANGELES  18 to 49 years  Female  Black
# 3 2021-11-01        NE           NA  18 to 49 years  Female  White
# 4 2020-09-01        TX           NA    0 - 17 years    Male  White
# 5 2022-06-01        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 6 2021-12-01        CA  LOS ANGELES  18 to 49 years  Female  Black
# 7 2021-11-01        NE           NA  18 to 49 years  Female  White
# 8 2022-06-01        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 9 2020-12-01        TX           NA       65+ years      NA     NA
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 1  Laboratory-confirmed case    Symptomatic      Yes  Missing      Yes
# 2  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 3  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 5  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 6  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 7  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 8  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 9  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 0                      Yes
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN

# %%
age_df = df.copy()
age_df = age_df.drop(['sex', 'race'], axis=1)
age_df.head()
# Out:
#   case_month res_state   res_county       age_group  \
# 0 2022-06-01        CA  LOS ANGELES  18 to 49 years
# 1 2020-12-01        TX           NA       65+ years
# 2 2021-12-01        CA  LOS ANGELES  18 to 49 years
# 3 2021-11-01        NE           NA  18 to 49 years
# 4 2020-09-01        TX           NA    0 - 17 years
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 1  Laboratory-confirmed case    Symptomatic      Yes  Missing      Yes
# 2  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 3  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
#
#   underlying_conditions_yn
# 0                      Yes
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
sex_df = df.copy()
sex_df = sex_df.drop(['age_group', 'race'], axis=1)
sex_df.head()
# Out:
#   case_month res_state   res_county     sex             current_status  \
# 0 2022-06-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 1 2020-12-01        TX           NA      NA  Laboratory-confirmed case
# 2 2021-12-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 3 2021-11-01        NE           NA  Female  Laboratory-confirmed case
# 4 2020-09-01        TX           NA    Male  Laboratory-confirmed case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0        Unknown       No  Missing  Missing                      Yes
# 1    Symptomatic      Yes  Missing      Yes                      NaN
# 2        Unknown       No  Missing  Missing                      NaN
# 3    Symptomatic  Missing  Missing  Missing                      NaN
# 4    Symptomatic       No  Missing  Missing                      NaN

# %%
race_df = df.copy()
race_df = race_df.drop(['age_group', 'sex'], axis=1)
race_df.head()
# Out:
#   case_month res_state   res_county   race             current_status  \
# 0 2022-06-01        CA  LOS ANGELES  Asian  Laboratory-confirmed case
# 1 2020-12-01        TX           NA     NA  Laboratory-confirmed case
# 2 2021-12-01        CA  LOS ANGELES  Black  Laboratory-confirmed case
# 3 2021-11-01        NE           NA  White  Laboratory-confirmed case
# 4 2020-09-01        TX           NA  White  Laboratory-confirmed case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0        Unknown       No  Missing  Missing                      Yes
# 1    Symptomatic      Yes  Missing      Yes                      NaN
# 2        Unknown       No  Missing  Missing                      NaN
# 3    Symptomatic  Missing  Missing  Missing                      NaN
# 4    Symptomatic       No  Missing  Missing                      NaN

# %%
age_df['age_group'].replace('Missing', pd.NA, inplace=True)
age_df.dropna(subset=['age_group'], inplace = True)
age_df = age_df[age_df['age_group'] != 'NA']
age_df.head(20)
# Out:
#    case_month res_state   res_county       age_group  \
# 0  2022-06-01        CA  LOS ANGELES  18 to 49 years
# 1  2020-12-01        TX           NA       65+ years
# 2  2021-12-01        CA  LOS ANGELES  18 to 49 years
# 3  2021-11-01        NE           NA  18 to 49 years
# 4  2020-09-01        TX           NA    0 - 17 years
# 5  2022-06-01        CA  LOS ANGELES  18 to 49 years
# 6  2021-12-01        CA  LOS ANGELES  18 to 49 years
# 7  2021-11-01        NE           NA  18 to 49 years
# 8  2022-06-01        CA  LOS ANGELES  18 to 49 years
# 9  2020-12-01        TX           NA       65+ years
# 10 2021-12-01        CA  LOS ANGELES  18 to 49 years
# 11 2021-11-01        NE           NA  18 to 49 years
# 12 2020-09-01        TX           NA    0 - 17 years
# 13 2022-06-01        CA  LOS ANGELES  18 to 49 years
# 14 2021-12-01        CA  LOS ANGELES  18 to 49 years
# 15 2021-11-01        NE           NA  18 to 49 years
# 16 2020-12-01        TX           NA       65+ years
# 17 2022-06-01        CA  LOS ANGELES  18 to 49 years
# 18 2021-12-01        CA  LOS ANGELES  18 to 49 years
# 19 2021-11-01        NE           NA  18 to 49 years
#
#                current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0   Laboratory-confirmed case        Unknown       No  Missing  Missing
# 1   Laboratory-confirmed case    Symptomatic      Yes  Missing      Yes
# 2   Laboratory-confirmed case        Unknown       No  Missing  Missing
# 3   Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4   Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 5   Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 6   Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 7   Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 8   Laboratory-confirmed case        Unknown       No  Missing  Missing
# 9   Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 10  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 11  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 12  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 13  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 14  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 15  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 16  Laboratory-confirmed case    Symptomatic      Yes  Missing       No
# 17  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 18  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 19              Probable Case    Symptomatic  Missing  Missing  Missing
#
#    underlying_conditions_yn
# 0                       Yes
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN

# %%
print(f"Age Group column contains: {age_df['age_group'].unique()}")
print(f"Length of age_df: {len(age_df)}")
# Out:
# Age Group column contains: ['18 to 49 years' '65+ years' '0 - 17 years' '50 to 64 years']
# Length of age_df: 9615921

# %%
sex_df['sex'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
sex_df = sex_df[sex_df['sex'] != 'NA']
sex_df.dropna(subset=['sex'], inplace = True)
sex_df.head(20)
# Out:
#    case_month res_state   res_county     sex             current_status  \
# 0  2022-06-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 2  2021-12-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 3  2021-11-01        NE           NA  Female  Laboratory-confirmed case
# 4  2020-09-01        TX           NA    Male  Laboratory-confirmed case
# 5  2022-06-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 6  2021-12-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 7  2021-11-01        NE           NA  Female  Laboratory-confirmed case
# 8  2022-06-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 10 2021-12-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 11 2021-11-01        NE           NA  Female  Laboratory-confirmed case
# 12 2020-09-01        TX           NA    Male  Laboratory-confirmed case
# 13 2022-06-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 14 2021-12-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 15 2021-11-01        NE           NA  Female  Laboratory-confirmed case
# 17 2022-06-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 18 2021-12-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 19 2021-11-01        NE           NA  Female              Probable Case
# 20 2020-09-01        TX           NA    Male  Laboratory-confirmed case
# 21 2022-06-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
# 22 2021-12-01        CA  LOS ANGELES  Female  Laboratory-confirmed case
#
#    symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0         Unknown       No  Missing  Missing                      Yes
# 2         Unknown       No  Missing  Missing                      NaN
# 3     Symptomatic  Missing  Missing  Missing                      NaN
# 4     Symptomatic       No  Missing  Missing                      NaN
# 5     Symptomatic       No  Missing  Missing                      NaN
# 6     Symptomatic       No  Missing  Missing                      NaN
# 7     Symptomatic  Missing  Missing  Missing                      NaN
# 8         Unknown       No  Missing  Missing                      NaN
# 10    Symptomatic       No  Missing  Missing                      NaN
# 11    Symptomatic  Missing  Missing  Missing                      NaN
# 12        Missing  Missing  Missing  Missing                      NaN
# 13    Symptomatic       No  Missing  Missing                      NaN
# 14        Unknown       No  Missing  Missing                      NaN
# 15    Symptomatic  Missing  Missing  Missing                      NaN
# 17    Symptomatic       No  Missing  Missing                      NaN
# 18        Unknown       No  Missing  Missing                      NaN
# 19    Symptomatic  Missing  Missing  Missing                      NaN
# 20    Symptomatic       No  Missing       No                      NaN
# 21    Symptomatic       No  Missing  Missing                      NaN
# 22        Unknown       No  Missing  Missing                      NaN

# %%
print(f"Sex column contains: {sex_df['sex'].unique()}")
print(f"Length of sex_df: {len(sex_df)}")
# Out:
# Sex column contains: ['Female' 'Male' 'Other']
# Length of sex_df: 8969565

# %%
race_df['race'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
race_df = race_df[race_df['race'] != 'NA']
race_df.dropna(subset=['race'], inplace = True)
race_df.head(20)
# Out:
#    case_month res_state   res_county   race             current_status  \
# 0  2022-06-01        CA  LOS ANGELES  Asian  Laboratory-confirmed case
# 2  2021-12-01        CA  LOS ANGELES  Black  Laboratory-confirmed case
# 3  2021-11-01        NE           NA  White  Laboratory-confirmed case
# 4  2020-09-01        TX           NA  White  Laboratory-confirmed case
# 5  2022-06-01        CA  LOS ANGELES  Asian  Laboratory-confirmed case
# 6  2021-12-01        CA  LOS ANGELES  Black  Laboratory-confirmed case
# 7  2021-11-01        NE           NA  White  Laboratory-confirmed case
# 8  2022-06-01        CA  LOS ANGELES  Asian  Laboratory-confirmed case
# 10 2021-12-01        CA  LOS ANGELES  Black  Laboratory-confirmed case
# 11 2021-11-01        NE           NA  White  Laboratory-confirmed case
# 12 2020-09-01        TX           NA  White  Laboratory-confirmed case
# 13 2022-06-01        CA  LOS ANGELES  Asian  Laboratory-confirmed case
# 14 2021-12-01        CA  LOS ANGELES  Black  Laboratory-confirmed case
# 15 2021-11-01        NE           NA  White  Laboratory-confirmed case
# 17 2022-06-01        CA  LOS ANGELES  Asian  Laboratory-confirmed case
# 18 2021-12-01        CA  LOS ANGELES  Black  Laboratory-confirmed case
# 19 2021-11-01        NE           NA  White              Probable Case
# 20 2020-09-01        TX           NA  White  Laboratory-confirmed case
# 21 2022-06-01        CA  LOS ANGELES  Asian  Laboratory-confirmed case
# 22 2021-12-01        CA  LOS ANGELES  Black  Laboratory-confirmed case
#
#    symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0         Unknown       No  Missing  Missing                      Yes
# 2         Unknown       No  Missing  Missing                      NaN
# 3     Symptomatic  Missing  Missing  Missing                      NaN
# 4     Symptomatic       No  Missing  Missing                      NaN
# 5     Symptomatic       No  Missing  Missing                      NaN
# 6     Symptomatic       No  Missing  Missing                      NaN
# 7     Symptomatic  Missing  Missing  Missing                      NaN
# 8         Unknown       No  Missing  Missing                      NaN
# 10    Symptomatic       No  Missing  Missing                      NaN
# 11    Symptomatic  Missing  Missing  Missing                      NaN
# 12        Missing  Missing  Missing  Missing                      NaN
# 13    Symptomatic       No  Missing  Missing                      NaN
# 14        Unknown       No  Missing  Missing                      NaN
# 15    Symptomatic  Missing  Missing  Missing                      NaN
# 17    Symptomatic       No  Missing  Missing                      NaN
# 18        Unknown       No  Missing  Missing                      NaN
# 19    Symptomatic  Missing  Missing  Missing                      NaN
# 20    Symptomatic       No  Missing       No                      NaN
# 21    Symptomatic       No  Missing  Missing                      NaN
# 22        Unknown       No  Missing  Missing                      NaN

# %%
print(f"Race column contains: {race_df['race'].unique()}")
print(f"Length of race_df: {len(race_df)}")
# Out:
# Race column contains: ['Asian' 'Black' 'White' 'American Indian/Alaska Native'
#  'Native Hawaiian/Other Pacific Islander' 'Multiple/Other']
# Length of race_df: 6065484

# %%
age_df.to_csv('resources/demographic_analysis/age.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28176\3509769979.py in <module>
# ----> 1 age_df.to_csv('resources/demographic_analysis/age.csv', index = False)
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     309         df = self.obj.iloc[slicer]
#     310
# --> 311         res = df._mgr.to_native_types(**self._number_format)
#     312         data = [res.iget_values(i) for i in range(len(res.items))]
#     313
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\managers.py in to_native_types(self, **kwargs)
#     471         in formatting (repr / csv).
#     472         """
# --> 473         return self.apply("to_native_types", **kwargs)
#     474
#     475     @property
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in to_native_types(self, na_rep, quoting, **kwargs)
#     632     def to_native_types(self, na_rep="nan", quoting=None, **kwargs):
#     633         """convert to our native types format"""
# --> 634         result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     635         return self.make_block(result)
#     636
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2223     else:
#    2224
# -> 2225         mask = isna(values)
#    2226         itemsize = writers.word_len(na_rep)
#    2227
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     142     Name: 1, dtype: bool
#     143     """
# --> 144     return _isna(obj)
#     145
#     146
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna(obj, inf_as_na)
#     171         return False
#     172     elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 173         return _isna_array(obj, inf_as_na=inf_as_na)
#     174     elif isinstance(obj, ABCIndex):
#     175         # Try to use cached isna, which also short-circuits for integer dtypes
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py in _isna_array(values, inf_as_na)
#     253             result = values.isna()  # type: ignore[assignment]
#     254     elif is_string_or_object_np_dtype(values.dtype):
# --> 255         result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     256     elif needs_i8_conversion(dtype):
#     257         # this is the NaT pattern
#
# KeyboardInterrupt:

# %%
sex_df.to_csv('resources/demographic_analysis/sex.csv', index = False)

# %%
race_df.to_csv('resources/demographic_analysis/race.csv', index = False)

# %%
count = (age_df[(age_df['age_group'] == '18 to 49 years') & (age_df['death_yn'] == 'Yes')])
count.head()
# Out:
#        case_month res_state   res_county       age_group  \
# 375563 2022-01-01        CA  LOS ANGELES  18 to 49 years
# 376654 2022-01-01        CA  LOS ANGELES  18 to 49 years
# 376666 2022-01-01        CA  LOS ANGELES  18 to 49 years
# 378430 2022-01-01        CA  LOS ANGELES  18 to 49 years
# 378570 2022-01-01        CA  LOS ANGELES  18 to 49 years
#
#                    current_status symptom_status hosp_yn   icu_yn death_yn  \
# 375563  Laboratory-confirmed case        Unknown     Yes  Unknown      Yes
# 376654  Laboratory-confirmed case        Unknown      No  Missing      Yes
# 376666  Laboratory-confirmed case        Unknown     Yes      Yes      Yes
# 378430  Laboratory-confirmed case        Unknown     Yes  Unknown      Yes
# 378570  Laboratory-confirmed case    Symptomatic     Yes  Unknown      Yes
#
#        underlying_conditions_yn
# 375563                      NaN
# 376654                      NaN
# 376666                      NaN
# 378430                      NaN
# 378570                      NaN

# %%
len(count)
# Out:
# 889

# %%
len(age_df)
# Out:
# 9615921

# %%
age_df_subset = age_df.head(1000000)
sex_df_subset = sex_df.head(1000000)
race_df_subset = race_df.head(1000000)

age_df_subset.to_csv('resources/demographic_analysis/sample_age.csv', index = False)
sex_df_subset.to_csv('resources/demographic_analysis/sample_sex.csv', index = False)
race_df_subset.to_csv('resources/demographic_analysis/sample_race.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28176\4113953717.py in <module>
#       3 race_df_subset = race_df.head(1000000)
#       4
# ----> 5 age_df_subset.to_csv('resources/demographic_analysis/sample_age.csv', index = False)
#       6 sex_df_subset.to_csv('resources/demographic_analysis/sample_sex.csv', index = False)
#       7 race_df_subset.to_csv('resources/demographic_analysis/sample_race.csv', index = False)
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     309         df = self.obj.iloc[slicer]
#     310
# --> 311         res = df._mgr.to_native_types(**self._number_format)
#     312         data = [res.iget_values(i) for i in range(len(res.items))]
#     313
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\managers.py in to_native_types(self, **kwargs)
#     471         in formatting (repr / csv).
#     472         """
# --> 473         return self.apply("to_native_types", **kwargs)
#     474
#     475     @property
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in to_native_types(self, na_rep, quoting, **kwargs)
#     632     def to_native_types(self, na_rep="nan", quoting=None, **kwargs):
#     633         """convert to our native types format"""
# --> 634         result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     635         return self.make_block(result)
#     636
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2180         results_converted = []
#    2181         for i in range(len(values)):
# -> 2182             result = values[i, :]._format_native_types(na_rep=na_rep, **kwargs)
#    2183             results_converted.append(result.astype(object, copy=False))
#    2184         return np.vstack(results_converted)
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\pandas\core\arrays\_mixins.py in method(self, *args, **kwargs)
#      82     def method(self, *args, **kwargs):
#      83         if self.ndim == 1:
# ---> 84             return meth(self, *args, **kwargs)
#      85
#      86         flags = self._ndarray.flags
#
# KeyboardInterrupt:

# %% [markdown]
# # All three datasets for Tableau

# %%
tableau_df = df.copy()
tableau_df['age_group'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
tableau_df['sex'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
tableau_df['race'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
tableau_df.head()
# Out:
#   case_month res_state   res_county       age_group     sex   race  \
# 0 2022-06-01        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 1 2020-12-01        TX           NA       65+ years      NA     NA
# 2 2021-12-01        CA  LOS ANGELES  18 to 49 years  Female  Black
# 3 2021-11-01        NE           NA  18 to 49 years  Female  White
# 4 2020-09-01        TX           NA    0 - 17 years    Male  White
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 1  Laboratory-confirmed case    Symptomatic      Yes  Missing      Yes
# 2  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 3  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
#
#   underlying_conditions_yn
# 0                      Yes
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
tableau_df.dropna(subset=['age_group', 'sex', 'race'], inplace = True)

display(tableau_df.head(10))
print(len(tableau_df))
# Out:
#   case_month res_state   res_county       age_group     sex   race  \
# 0 2022-06-01        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 1 2020-12-01        TX           NA       65+ years      NA     NA
# 2 2021-12-01        CA  LOS ANGELES  18 to 49 years  Female  Black
# 3 2021-11-01        NE           NA  18 to 49 years  Female  White
# 4 2020-09-01        TX           NA    0 - 17 years    Male  White
# 5 2022-06-01        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 6 2021-12-01        CA  LOS ANGELES  18 to 49 years  Female  Black
# 7 2021-11-01        NE           NA  18 to 49 years  Female  White
# 8 2022-06-01        CA  LOS ANGELES  18 to 49 years  Female  Asian
# 9 2020-12-01        TX           NA       65+ years      NA     NA
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 1  Laboratory-confirmed case    Symptomatic      Yes  Missing      Yes
# 2  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 3  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 4  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 5  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 6  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 7  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 8  Laboratory-confirmed case        Unknown       No  Missing  Missing
# 9  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 0                      Yes
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 7763759

# %%
import numpy as np

tableau_df[['age_group', 'sex', 'race']] = tableau_df[['age_group', 'sex', 'race']].replace('NA', np.nan)

# %%
tableau_df.dropna(subset=['age_group', 'sex', 'race'], inplace = True)

# %%
tableau_columns = ['age_group', 'sex', 'race']
for col in tableau_columns: 
    print(col, tableau_df[col].unique())
# Out:
# age_group ['50 to 64 years' '18 to 49 years' '65+ years' '0 - 17 years']
# sex ['Female' 'Male' 'Other']
# race ['White' 'Black' 'Asian' 'Multiple/Other' 'American Indian/Alaska Native'
#  'Native Hawaiian/Other Pacific Islander']

# %%
display(tableau_df.head(10))
print(len(tableau_df))
# Out:
#    case_month res_state    res_county       age_group     sex   race  \
# 0  2022-11-01        HI      HONOLULU  50 to 64 years  Female  White
# 2  2021-08-01        ID           ADA  18 to 49 years    Male  White
# 6  2021-01-01        SC   SPARTANBURG  18 to 49 years  Female  Black
# 7  2022-05-01        MD  ANNE ARUNDEL  18 to 49 years    Male  White
# 8  2022-03-01        FL    MIAMI-DADE  50 to 64 years    Male  White
# 10 2022-05-01        NJ         UNION  50 to 64 years    Male  Asian
# 11 2023-02-01        MI        INGHAM  18 to 49 years  Female  Black
# 12 2022-07-01        FL     ST. LUCIE  18 to 49 years  Female  White
# 13 2022-01-01        MN        DAKOTA  50 to 64 years  Female  White
# 14 2021-10-01        MI     KALAMAZOO  18 to 49 years    Male  White
#
#                current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0   Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 2   Laboratory-confirmed case        Unknown       No  Missing       No
# 6   Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 7               Probable Case    Symptomatic  Missing  Missing       No
# 8   Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 10  Laboratory-confirmed case    Symptomatic      Yes  Missing       No
# 11  Laboratory-confirmed case        Missing  Missing  Missing  Unknown
# 12  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 13  Laboratory-confirmed case    Symptomatic  Missing  Missing       No
# 14              Probable Case        Missing  Missing  Missing  Unknown
#
#    underlying_conditions_yn
# 0                       NaN
# 2                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      Yes
# 14                      NaN
# 6389751

# %%
tableau_df.to_csv('resources/demographic_analysis/tableau.csv', index = False)

# %% [markdown]
# # Cleaned DataFrame for Machine Learning

# %%
clean_df = df.copy()
clean_df = clean_df.drop(['case_month', 'res_state', 'res_county', 'hosp_yn'], axis=1)
clean_df.head(10)
# Out:
#         age_group     sex   race             current_status symptom_status  \
# 0  18 to 49 years  Female  Asian  Laboratory-confirmed case        Unknown
# 1       65+ years      NA     NA  Laboratory-confirmed case    Symptomatic
# 2  18 to 49 years  Female  Black  Laboratory-confirmed case        Unknown
# 3  18 to 49 years  Female  White  Laboratory-confirmed case    Symptomatic
# 4    0 - 17 years    Male  White  Laboratory-confirmed case    Symptomatic
# 5  18 to 49 years  Female  Asian  Laboratory-confirmed case    Symptomatic
# 6  18 to 49 years  Female  Black  Laboratory-confirmed case    Symptomatic
# 7  18 to 49 years  Female  White  Laboratory-confirmed case    Symptomatic
# 8  18 to 49 years  Female  Asian  Laboratory-confirmed case        Unknown
# 9       65+ years      NA     NA  Laboratory-confirmed case        Missing
#
#     icu_yn death_yn underlying_conditions_yn
# 0  Missing  Missing                      Yes
# 1  Missing      Yes                      NaN
# 2  Missing  Missing                      NaN
# 3  Missing  Missing                      NaN
# 4  Missing  Missing                      NaN
# 5  Missing  Missing                      NaN
# 6  Missing  Missing                      NaN
# 7  Missing  Missing                      NaN
# 8  Missing  Missing                      NaN
# 9  Missing  Missing                      NaN

# %%
for col in clean_df.columns: 
    print(col, df[col].unique())
# Out:
# age_group ['18 to 49 years' '65+ years' '0 - 17 years' 'Missing' 'NA'
#  '50 to 64 years']
# sex ['Female' 'NA' 'Male' 'Other' 'Unknown' 'Missing']
# race ['Asian' 'NA' 'Black' 'White' 'Unknown' 'American Indian/Alaska Native'
#  'Missing' 'Native Hawaiian/Other Pacific Islander' 'Multiple/Other']
# current_status ['Laboratory-confirmed case' 'Probable Case']
# symptom_status ['Unknown' 'Symptomatic' 'Missing' 'Asymptomatic']
# icu_yn ['Missing' 'No' 'Unknown' 'Yes']
# death_yn ['Missing' 'Yes' 'No' 'NA' 'Unknown']
# underlying_conditions_yn ['Yes' nan 'No']

# %%
clean_df['age_group'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
clean_df['sex'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
clean_df['race'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
clean_df['symptom_status'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
clean_df['icu_yn'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
clean_df['death_yn'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)

clean_df = clean_df[clean_df[['age_group', 'sex', 'race', 'symptom_status', 'icu_yn', 'death_yn']] != 'NA']
clean_df.dropna(subset=['age_group', 'sex', 'race', 'symptom_status', 'icu_yn', 'death_yn'], inplace = True)
clean_df.head()
# Out:
#             age_group     sex   race current_status symptom_status icu_yn  \
# 8111   18 to 49 years  Female  White            NaN    Symptomatic     No
# 20608       65+ years  Female  Asian            NaN    Symptomatic    Yes
# 20644       65+ years  Female  Asian            NaN    Symptomatic    Yes
# 20876       65+ years  Female  Asian            NaN    Symptomatic    Yes
# 20912       65+ years  Female  Asian            NaN    Symptomatic    Yes
#
#       death_yn underlying_conditions_yn
# 8111        No                      NaN
# 20608      Yes                      NaN
# 20644      Yes                      NaN
# 20876      Yes                      NaN
# 20912      Yes                      NaN

# %%
for col in clean_df.columns: 
    print(col, clean_df[col].unique())
# Out:
# age_group ['18 to 49 years' '65+ years' '50 to 64 years' '0 - 17 years']
# sex ['Female' 'Male']
# race ['White' 'Asian' 'Black' 'American Indian/Alaska Native' 'Multiple/Other'
#  'Native Hawaiian/Other Pacific Islander']
# current_status [nan]
# symptom_status ['Symptomatic' 'Asymptomatic']
# icu_yn ['No' 'Yes']
# death_yn ['No' 'Yes']
# underlying_conditions_yn [nan]

# %%
new_clean_df = clean_df.drop(['current_status', 'underlying_conditions_yn'], axis=1)
new_clean_df['death_yn'] = new_clean_df['death_yn'].replace({'Yes': 1, 'No': 0})
new_clean_df.head()
# Out:
#             age_group     sex   race symptom_status icu_yn  death_yn
# 8111   18 to 49 years  Female  White    Symptomatic     No         0
# 20608       65+ years  Female  Asian    Symptomatic    Yes         1
# 20644       65+ years  Female  Asian    Symptomatic    Yes         1
# 20876       65+ years  Female  Asian    Symptomatic    Yes         1
# 20912       65+ years  Female  Asian    Symptomatic    Yes         1

# %%
new_clean_df.dtypes
# Out:
# age_group         object
# sex               object
# race              object
# symptom_status    object
# icu_yn            object
# death_yn           int64
# dtype: object

# %%
encoded_df = pd.get_dummies(new_clean_df, columns = ['age_group', 'sex', 'race', 'symptom_status', 'icu_yn'])
encoded_df.head(25)
# Out:
#        death_yn  age_group_0 - 17 years  age_group_18 to 49 years  \
# 8111          0                       0                         1
# 20608         1                       0                         0
# 20644         1                       0                         0
# 20876         1                       0                         0
# 20912         1                       0                         0
# 20916         1                       0                         0
# 21032         1                       0                         0
# 21044         1                       0                         0
# 21056         1                       0                         0
# 21164         1                       0                         0
# 21304         1                       0                         0
# 31087         1                       0                         0
# 31090         0                       0                         0
# 31115         1                       0                         0
# 31119         1                       0                         0
# 31127         1                       0                         0
# 31507         1                       0                         0
# 31555         1                       0                         0
# 31678         0                       0                         0
# 31867         1                       0                         0
# 32002         0                       0                         0
# 32439         0                       0                         0
# 41380         0                       0                         1
# 46428         1                       0                         0
# 46464         1                       0                         0
#
#        age_group_50 to 64 years  age_group_65+ years  sex_Female  sex_Male  \
# 8111                          0                    0           1         0
# 20608                         0                    1           1         0
# 20644                         0                    1           1         0
# 20876                         0                    1           1         0
# 20912                         0                    1           1         0
# 20916                         0                    1           1         0
# 21032                         0                    1           1         0
# 21044                         0                    1           1         0
# 21056                         0                    1           1         0
# 21164                         0                    1           1         0
# 21304                         0                    1           1         0
# 31087                         0                    1           0         1
# 31090                         0                    1           0         1
# 31115                         0                    1           0         1
# 31119                         0                    1           0         1
# 31127                         0                    1           0         1
# 31507                         0                    1           0         1
# 31555                         0                    1           0         1
# 31678                         0                    1           0         1
# 31867                         0                    1           0         1
# 32002                         0                    1           0         1
# 32439                         0                    1           0         1
# 41380                         0                    0           1         0
# 46428                         0                    1           1         0
# 46464                         0                    1           1         0
#
#        race_American Indian/Alaska Native  race_Asian  race_Black  \
# 8111                                    0           0           0
# 20608                                   0           1           0
# 20644                                   0           1           0
# 20876                                   0           1           0
# 20912                                   0           1           0
# 20916                                   0           1           0
# 21032                                   0           1           0
# 21044                                   0           1           0
# 21056                                   0           1           0
# 21164                                   0           1           0
# 21304                                   0           1           0
# 31087                                   0           0           0
# 31090                                   0           0           0
# 31115                                   0           0           0
# 31119                                   0           0           0
# 31127                                   0           0           0
# 31507                                   0           0           0
# 31555                                   0           0           0
# 31678                                   0           0           0
# 31867                                   0           0           0
# 32002                                   0           0           0
# 32439                                   0           0           0
# 41380                                   0           0           1
# 46428                                   0           0           1
# 46464                                   0           0           1
#
#        race_Multiple/Other  race_Native Hawaiian/Other Pacific Islander  \
# 8111                     0                                            0
# 20608                    0                                            0
# 20644                    0                                            0
# 20876                    0                                            0
# 20912                    0                                            0
# 20916                    0                                            0
# 21032                    0                                            0
# 21044                    0                                            0
# 21056                    0                                            0
# 21164                    0                                            0
# 21304                    0                                            0
# 31087                    0                                            0
# 31090                    0                                            0
# 31115                    0                                            0
# 31119                    0                                            0
# 31127                    0                                            0
# 31507                    0                                            0
# 31555                    0                                            0
# 31678                    0                                            0
# 31867                    0                                            0
# 32002                    0                                            0
# 32439                    0                                            0
# 41380                    0                                            0
# 46428                    0                                            0
# 46464                    0                                            0
#
#        race_White  symptom_status_Asymptomatic  symptom_status_Symptomatic  \
# 8111            1                            0                           1
# 20608           0                            0                           1
# 20644           0                            0                           1
# 20876           0                            0                           1
# 20912           0                            0                           1
# 20916           0                            0                           1
# 21032           0                            0                           1
# 21044           0                            0                           1
# 21056           0                            0                           1
# 21164           0                            0                           1
# 21304           0                            0                           1
# 31087           1                            0                           1
# 31090           1                            0                           1
# 31115           1                            0                           1
# 31119           1                            0                           1
# 31127           1                            0                           1
# 31507           1                            0                           1
# 31555           1                            0                           1
# 31678           1                            0                           1
# 31867           1                            0                           1
# 32002           1                            0                           1
# 32439           1                            1                           0
# 41380           0                            0                           1
# 46428           0                            0                           1
# 46464           0                            0                           1
#
#        icu_yn_No  icu_yn_Yes
# 8111           1           0
# 20608          0           1
# 20644          0           1
# 20876          0           1
# 20912          0           1
# 20916          0           1
# 21032          0           1
# 21044          0           1
# 21056          0           1
# 21164          0           1
# 21304          0           1
# 31087          1           0
# 31090          1           0
# 31115          1           0
# 31119          1           0
# 31127          1           0
# 31507          1           0
# 31555          0           1
# 31678          1           0
# 31867          0           1
# 32002          1           0
# 32439          1           0
# 41380          1           0
# 46428          0           1
# 46464          0           1

# %%
encoded_df['death_yn'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Set up for machine learning mortality model
y = encoded_df['death_yn']
X = encoded_df.drop(columns= 'death_yn')

# %% [markdown]
# # Logistic Regression Attempt

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
   y, random_state=1, stratify=y)

# %%
# Initiate similar to Module #18

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
   max_iter=10000,
   random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=1)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print("\nClassification Report: \n")
report = classification_report(y_test, y_pred)
print(report)
# Out:
# Accuracy Score: 0.9742631520409298
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     43345
#            1       0.68      0.53      0.59      1610
#
#     accuracy                           0.97     44955
#    macro avg       0.83      0.76      0.79     44955
# weighted avg       0.97      0.97      0.97     44955

# %%
cm_log = confusion_matrix(y_test, y_pred)
cm_log_df = pd.DataFrame(
    cm_log, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_log_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0        42949          396
# Actual 1          761          849

# %% [markdown]
# # SVC

# %%
X_train_SVC, X_test_SVC, y_train_SVC, y_test_SVC = train_test_split(X,
   y,  random_state=1, stratify=y)
X_train_SVC.shape
# Out:
# (134864, 16)

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')

# %%
model.fit(X_train_SVC, y_train_SVC)
# Out:
# SVC(kernel='linear')

# %%
y_pred_SVC = model.predict(X_test_SVC)

# %%
cm_SVC = confusion_matrix(y_test_SVC, y_pred_SVC)
cm_SVC_df = pd.DataFrame(
    cm_SVC, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_SVC_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0        42940          405
# Actual 1          755          855

# %%
print(f"Accuracy Score: {accuracy_score(y_test_SVC, y_pred_SVC)}")
print(classification_report(y_test_SVC, y_pred_SVC))
# Out:
# Accuracy Score: 0.974196418640863
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     43345
#            1       0.68      0.53      0.60      1610
#
#     accuracy                           0.97     44955
#    macro avg       0.83      0.76      0.79     44955
# weighted avg       0.97      0.97      0.97     44955

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
X_train_RF, X_test_RF, y_train_RF, y_test_RF = train_test_split(X, y, random_state=1)

# %%
scaler = StandardScaler()
X_scaler = scaler.fit(X_train_RF)

X_train_scaled_RF = X_scaler.transform(X_train_RF)
X_test_scaled_RF = X_scaler.transform(X_test_RF)

# %%
rf_model = RandomForestClassifier(n_estimators=128, random_state=1) 
rf_model = rf_model.fit(X_train_scaled_RF, y_train_RF)

# %%
predictions_RF = rf_model.predict(X_test_scaled_RF)
cm = confusion_matrix(y_test_RF, predictions_RF)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# %%
acc_score_RF = accuracy_score(y_test_RF, predictions_RF)

# %%
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score_RF}")
print("Classification Report")
print(classification_report(y_test_RF, predictions_RF))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0        42763          590
# Actual 1          576         1026
# Accuracy Score : 0.9740629518407297
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     43353
#            1       0.63      0.64      0.64      1602
#
#     accuracy                           0.97     44955
#    macro avg       0.81      0.81      0.81     44955
# weighted avg       0.97      0.97      0.97     44955

# %% [markdown]
# # Random Oversampler

# %%
from collections import Counter
X_train_ROS, X_test_ROS, y_train_ROS, y_test_ROS = train_test_split(X, y, random_state=1)
Counter(y_train)
# Out:
# Counter({0: 130036, 1: 4828})

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)

X_resampled_ROS, y_resampled_ROS = ros.fit_resample(X_train_ROS, y_train_ROS)

# %%
model_ROS = LogisticRegression(solver='lbfgs', max_iter=500, random_state=1)
model_ROS.fit(X_resampled_ROS, y_resampled_ROS)
# Out:
# LogisticRegression(max_iter=500, random_state=1)

# %%
y_pred_ROS = model.predict(X_test_ROS)

cm_ROS = confusion_matrix(y_test_ROS, y_pred_ROS)
cm_df_ROS = pd.DataFrame(
    cm_ROS, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# %%
from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import balanced_accuracy_score

acc_score_ROS= balanced_accuracy_score(y_test_RF, y_pred_ROS)

print("Confusion Matrix")
display(cm_df_ROS)
print(f"Accuracy Score : {acc_score_ROS}")
print("Classification Report")
print(classification_report_imbalanced(y_test_RF, y_pred_ROS))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0        42906          447
# Actual 1          735          867
# Accuracy Score : 0.7654438983655732
# Classification Report
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.98      0.99      0.54      0.99      0.73      0.56     43353
#           1       0.66      0.54      0.99      0.59      0.73      0.51      1602
#
# avg / total       0.97      0.97      0.56      0.97      0.73      0.56     44955

# %% [markdown]
# # SMOTEENN

# %%
X_train_SMOTEENN, X_test_SMOTEENN, y_train_SMOTEENN, y_test_SMOTEENN = train_test_split(X, y, random_state=1)

# %%
from imblearn.combine import SMOTEENN
smote_enn = SMOTEENN(random_state=1)
X_resampled_SMOTEENN, y_resampled_SMOTEENN = smote_enn.fit_resample(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28176\2453216599.py in <module>
#       1 from imblearn.combine import SMOTEENN
#       2 smote_enn = SMOTEENN(random_state=1)
# ----> 3 X_resampled_SMOTEENN, y_resampled_SMOTEENN = smote_enn.fit_resample(X, y)
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      86         )
#      87
# ---> 88         output = self._fit_resample(X, y)
#      89
#      90         y_ = (
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\imblearn\combine\_smote_enn.py in _fit_resample(self, X, y)
#     159
#     160         X_res, y_res = self.smote_.fit_resample(X, y)
# --> 161         return self.enn_.fit_resample(X_res, y_res)
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      86         )
#      87
# ---> 88         output = self._fit_resample(X, y)
#      89
#      90         y_ = (
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\imblearn\under_sampling\_prototype_selection\_edited_nearest_neighbours.py in _fit_resample(self, X, y)
#     163                 X_class = _safe_indexing(X, target_class_indices)
#     164                 y_class = _safe_indexing(y, target_class_indices)
# --> 165                 nnhood_idx = self.nn_.kneighbors(X_class, return_distance=False)[:, 1:]
#     166                 nnhood_label = y[nnhood_idx]
#     167                 if self.kind_sel == "mode":
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     750                 kwds = self.effective_metric_params_
#     751
# --> 752             chunked_results = list(
#     753                 pairwise_distances_chunked(
#     754                     X,
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1724         if reduce_func is not None:
#    1725             chunk_size = D_chunk.shape[0]
# -> 1726             D_chunk = reduce_func(D_chunk, sl.start)
#    1727             _check_chunk_size(D_chunk, chunk_size)
#    1728         yield D_chunk
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _kneighbors_reduce_func(self, dist, start, n_neighbors, return_distance)
#     632         """
#     633         sample_range = np.arange(dist.shape[0])[:, None]
# --> 634         neigh_ind = np.argpartition(dist, n_neighbors - 1, axis=1)
#     635         neigh_ind = neigh_ind[:, :n_neighbors]
#     636         # argpartition doesn't guarantee sorted order, so we sort again
#
# <__array_function__ internals> in argpartition(*args, **kwargs)
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in argpartition(a, kth, axis, kind, order)
#     837     --------
#     838     partition : Describes partition algorithms used.
# --> 839     ndarray.partition : Inplace partition.
#     840     argsort : Full indirect sort.
#     841     take_along_axis : Apply ``index_array`` from argpartition
#
# c:\Users\Khanh Phan\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
model_SMOTEENN = LogisticRegression(solver='lbfgs', random_state=1)
model_SMOTEENN.fit(X_resampled_SMOTEENN, y_resampled_SMOTEENN)

# %%
y_pred_SMOTEENN = model_SMOTEENN.predict(X_test)
cm_SMOTEENN = confusion_matrix(y_test_ROS, y_pred_ROS)
cm_df_SMOTEENN = pd.DataFrame(
    cm_SMOTEENN, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# %%
acc_score_SMOTEENN = balanced_accuracy_score(y_test_SMOTEENN, y_pred_SMOTEENN)

print("Confusion Matrix")
display(cm_df_SMOTEENN)
print(f"Accuracy Score : {acc_score_SMOTEENN}")
print("Classification Report")
print(classification_report_imbalanced(y_test_SMOTEENN, y_pred_SMOTEENN))
