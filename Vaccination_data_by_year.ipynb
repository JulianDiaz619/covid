# %%
import pandas as pd

# %%
covid_vacc_df = pd.read_csv('us_state_vaccinations.csv')
covid_vacc_df.head()
# Out:
#         date location  total_vaccinations  total_distributed  \
# 0  1/12/2021  Alabama             78134.0           377025.0
# 1  1/13/2021  Alabama             84040.0           378975.0
# 2  1/14/2021  Alabama             92300.0           435350.0
# 3  1/15/2021  Alabama            100567.0           444650.0
# 4  1/16/2021  Alabama                 NaN                NaN
#
#    people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0            70861.0                                 0.15
# 1            74792.0                                 0.19
# 2            80480.0                                  NaN
# 3            86956.0                                 0.28
# 4                NaN                                  NaN
#
#    total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                            1.59                   7270.0
# 1                            1.71                   9245.0
# 2                            1.88                      NaN
# ...

# %%
covid_vacc_df.isnull().sum()
# Out:
# date                                       0
# location                                   0
# total_vaccinations                     20148
# total_distributed                      20408
# people_vaccinated                      20412
# people_fully_vaccinated_per_hundred    22014
# total_vaccinations_per_hundred         21915
# people_fully_vaccinated                20492
# people_vaccinated_per_hundred          21939
# distributed_per_hundred                21935
# daily_vaccinations_raw                 24034
# daily_vaccinations                        65
# daily_vaccinations_per_million          2807
# share_doses_used                       20408
# total_boosters                         34564
# total_boosters_per_hundred             35411
# dtype: int64

# %%
covid_vacc_df.dtypes
# Out:
# date                                    object
# location                                object
# total_vaccinations                     float64
# total_distributed                      float64
# people_vaccinated                      float64
# people_fully_vaccinated_per_hundred    float64
# total_vaccinations_per_hundred         float64
# people_fully_vaccinated                float64
# people_vaccinated_per_hundred          float64
# distributed_per_hundred                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# daily_vaccinations_per_million         float64
# share_doses_used                       float64
# total_boosters                         float64
# total_boosters_per_hundred             float64
# dtype: object

# %%
covid_vacc_df_drop = covid_vacc_df.drop(columns=["total_vaccinations","total_distributed","total_vaccinations_per_hundred","distributed_per_hundred","daily_vaccinations_raw","daily_vaccinations","daily_vaccinations_per_million","share_doses_used","total_boosters","total_boosters_per_hundred"])
covid_vacc_df_drop.head()
# Out:
#         date location  people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0  1/12/2021  Alabama            70861.0                                 0.15
# 1  1/13/2021  Alabama            74792.0                                 0.19
# 2  1/14/2021  Alabama            80480.0                                  NaN
# 3  1/15/2021  Alabama            86956.0                                 0.28
# 4  1/16/2021  Alabama                NaN                                  NaN
#
#    people_fully_vaccinated  people_vaccinated_per_hundred
# 0                   7270.0                           1.45
# 1                   9245.0                           1.53
# 2                      NaN                           1.64
# 3                  13488.0                           1.77
# 4                      NaN                            NaN

# %%
covid_vacc_df_drop.isnull().sum()
# Out:
# date                                       0
# location                                   0
# people_vaccinated                      20412
# people_fully_vaccinated_per_hundred    22014
# people_fully_vaccinated                20492
# people_vaccinated_per_hundred          21939
# dtype: int64

# %%
covid_vacc_df_dropnull = covid_vacc_df_drop.dropna()
covid_vacc_df_dropnull.isnull().sum()
# Out:
# date                                   0
# location                               0
# people_vaccinated                      0
# people_fully_vaccinated_per_hundred    0
# people_fully_vaccinated                0
# people_vaccinated_per_hundred          0
# dtype: int64

# %%
covid_vacc_df_dropnull.head()
# Out:
#         date location  people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0  1/12/2021  Alabama            70861.0                                 0.15
# 1  1/13/2021  Alabama            74792.0                                 0.19
# 3  1/15/2021  Alabama            86956.0                                 0.28
# 7  1/19/2021  Alabama           114319.0                                 0.33
# 8  1/20/2021  Alabama           121113.0                                 0.37
#
#    people_fully_vaccinated  people_vaccinated_per_hundred
# 0                   7270.0                           1.45
# 1                   9245.0                           1.53
# 3                  13488.0                           1.77
# 7                  16346.0                           2.33
# 8                  17956.0                           2.47

# %%
covid_vacc_df_dropnull.head()
# Out:
#         date location  people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0  1/12/2021  Alabama            70861.0                                 0.15
# 1  1/13/2021  Alabama            74792.0                                 0.19
# 3  1/15/2021  Alabama            86956.0                                 0.28
# 7  1/19/2021  Alabama           114319.0                                 0.33
# 8  1/20/2021  Alabama           121113.0                                 0.37
#
#    people_fully_vaccinated  people_vaccinated_per_hundred
# 0                   7270.0                           1.45
# 1                   9245.0                           1.53
# 3                  13488.0                           1.77
# 7                  16346.0                           2.33
# 8                  17956.0                           2.47

# %%
covid_vacc_df_copy = covid_vacc_df_dropnull.copy()

# %%
covid_vacc_df_copy['date'] = pd.to_datetime(covid_vacc_df_copy['date'])
covid_vacc_df_copy['year'] = covid_vacc_df_copy['date'].dt.year

# %%
covid_vacc_df_copy.head()
# Out:
#         date location  people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0 2021-01-12  Alabama            70861.0                                 0.15
# 1 2021-01-13  Alabama            74792.0                                 0.19
# 3 2021-01-15  Alabama            86956.0                                 0.28
# 7 2021-01-19  Alabama           114319.0                                 0.33
# 8 2021-01-20  Alabama           121113.0                                 0.37
#
#    people_fully_vaccinated  people_vaccinated_per_hundred  year
# 0                   7270.0                           1.45  2021
# 1                   9245.0                           1.53  2021
# 3                  13488.0                           1.77  2021
# 7                  16346.0                           2.33  2021
# 8                  17956.0                           2.47  2021

# %%
covid_vacc_df_1 = covid_vacc_df_copy.drop(columns=["date"])
covid_vacc_df_1.head()
# Out:
#   location  people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0  Alabama            70861.0                                 0.15
# 1  Alabama            74792.0                                 0.19
# 3  Alabama            86956.0                                 0.28
# 7  Alabama           114319.0                                 0.33
# 8  Alabama           121113.0                                 0.37
#
#    people_fully_vaccinated  people_vaccinated_per_hundred  year
# 0                   7270.0                           1.45  2021
# 1                   9245.0                           1.53  2021
# 3                  13488.0                           1.77  2021
# 7                  16346.0                           2.33  2021
# 8                  17956.0                           2.47  2021

# %%
covid_vacc_df_2 = covid_vacc_df_1[["year","location","people_vaccinated","people_vaccinated_per_hundred","people_fully_vaccinated","people_fully_vaccinated_per_hundred"]]
covid_vacc_df_2.head()
# Out:
#    year location  people_vaccinated  people_vaccinated_per_hundred  \
# 0  2021  Alabama            70861.0                           1.45
# 1  2021  Alabama            74792.0                           1.53
# 3  2021  Alabama            86956.0                           1.77
# 7  2021  Alabama           114319.0                           2.33
# 8  2021  Alabama           121113.0                           2.47
#
#    people_fully_vaccinated  people_fully_vaccinated_per_hundred
# 0                   7270.0                                 0.15
# 1                   9245.0                                 0.19
# 3                  13488.0                                 0.28
# 7                  16346.0                                 0.33
# 8                  17956.0                                 0.37

# %%
last_vaccinations_df = pd.DataFrame(columns=['location', 'people_vaccinated','people_fully_vaccinated','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred'])

for state in covid_vacc_df_2['location'].unique():
    for year in [2021, 2022, 2023]:
        last_vaccinations_df = last_vaccinations_df.append(
            covid_vacc_df_2.loc[(covid_vacc_df_2['location']==state) & (covid_vacc_df_2['year']==year)].tail(1)[['location', 'people_vaccinated','people_fully_vaccinated','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred', 'year']]
        )

last_vaccinations_df.reset_index(drop=True, inplace=True)
last_vaccinations_df
# Out:
#       location  people_vaccinated  people_fully_vaccinated  \
# 0      Alabama          2868764.0                2335344.0
# 1      Alabama          3178492.0                2599499.0
# 2      Alabama          3190565.0                2609715.0
# 3       Alaska           475688.0                 412110.0
# 4       Alaska           532210.0                 475125.0
# ..         ...                ...                      ...
# 178  Wisconsin          4359529.0                3957621.0
# 179  Wisconsin          4382474.0                3977707.0
# 180    Wyoming           323245.0                 275046.0
# 181    Wyoming           351498.0                 306301.0
# 182    Wyoming           353233.0                 307311.0
#
#      people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            58.51                                47.63
# 1                            64.83                                53.02
# ...

# %%
grouped_df = last_vaccinations_df.groupby(['location', 'year']).agg({'people_vaccinated': 'sum','people_fully_vaccinated':'sum','people_vaccinated_per_hundred':'sum','people_fully_vaccinated_per_hundred':'sum'})
grouped_df.head()
# Out:
#                  people_vaccinated  people_fully_vaccinated  \
# location year
# Alabama  2021.0          2868764.0                2335344.0
#          2022.0          3178492.0                2599499.0
#          2023.0          3190565.0                2609715.0
# Alaska   2021.0           475688.0                 412110.0
#          2022.0           532210.0                 475125.0
#
#                  people_vaccinated_per_hundred  \
# location year
# Alabama  2021.0                          58.51
#          2022.0                          64.83
#          2023.0                          65.07
# Alaska   2021.0                          65.03
#          2022.0                          72.75
#
#                  people_fully_vaccinated_per_hundred
# location year
# Alabama  2021.0                                47.63
#          2022.0                                53.02
#          2023.0                                53.22
# Alaska   2021.0                                56.33
# ...

# %%
grouped_df.to_csv('vaccinattion_data_by_year.csv', index=True)
