# %%
import pandas as pd

# %%
json = "https://data.cdc.gov/resource/n8mc-b4w4.json?$limit=10000000"
df = pd.read_json(json)
df.head(10)
# Out:
#   case_month res_state  state_fips_code      res_county county_fips_code  \
# 0    2022-02        TX               48         HIDALGO            48215
# 1    2020-11        IN               18          PORTER            18127
# 2    2021-02        OH               39         LICKING            39089
# 3    2021-03        CA                6      STANISLAUS            06099
# 4    2021-08        TX               48       JEFFERSON            48245
# 5    2022-01        MI               26       WASHTENAW            26161
# 6    2022-01        GA               13         CHATHAM            13051
# 7    2022-11        CA                6       SAN DIEGO            06073
# 8    2022-11        MI               26          MONROE            26115
# 9    2022-03        CA                6  SAN BERNARDINO            06071
#
#         age_group     sex     race            ethnicity  case_onset_interval  \
# 0    0 - 17 years  Female    White      Hispanic/Latino                 -5.0
# 1       65+ years    Male    White  Non-Hispanic/Latino                  NaN
# 2       65+ years  Female  Unknown              Unknown                  0.0
# 3  50 to 64 years    Male  Unknown              Unknown                  NaN
# 4  18 to 49 years    Male    White              Missing                  NaN
# 5  50 to 64 years    Male    White      Hispanic/Latino                  0.0
# 6  18 to 49 years    Male    Black  Non-Hispanic/Latino                  0.0
# 7       65+ years  Female    White  Non-Hispanic/Latino                  0.0
# 8  50 to 64 years    Male    White  Non-Hispanic/Latino                  NaN
# 9  18 to 49 years  Female       NA                   NA                  NaN
#
#    process exposure_yn             current_status symptom_status  hosp_yn  \
# 0  Missing     Missing              Probable Case    Symptomatic       No
# 1  Missing     Missing  Laboratory-confirmed case        Missing      Yes
# 2  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
# 3  Missing     Missing  Laboratory-confirmed case        Unknown  Missing
# 4  Missing     Missing  Laboratory-confirmed case        Missing  Missing
# 5  Missing     Missing              Probable Case    Symptomatic  Missing
# 6  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
# 7  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 8  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 9  Missing     Missing  Laboratory-confirmed case        Unknown       No
#
#     icu_yn death_yn  case_positive_specimen underlying_conditions_yn
# 0  Missing  Missing                     NaN                      NaN
# 1  Missing       No                     0.0                      NaN
# 2  Missing  Unknown                     NaN                      NaN
# 3  Missing  Missing                     NaN                      NaN
# 4  Missing  Missing                     NaN                      NaN
# 5  Missing       NA                     NaN                      NaN
# 6  Missing  Missing                     NaN                      NaN
# 7  Missing  Missing                     NaN                      NaN
# 8  Missing  Unknown                     NaN                      NaN
# 9  Missing  Missing                     NaN                      NaN

# %%
df = df.drop(['state_fips_code', 'county_fips_code', 'ethnicity', 'process', 'exposure_yn', 'case_onset_interval', 'case_positive_specimen', 'exposure_yn', 'case_onset_interval', 'case_positive_specimen'], axis=1)
df.head(10)
# Out:
#   case_month res_state      res_county       age_group     sex     race  \
# 0    2022-02        TX         HIDALGO    0 - 17 years  Female    White
# 1    2020-11        IN          PORTER       65+ years    Male    White
# 2    2021-02        OH         LICKING       65+ years  Female  Unknown
# 3    2021-03        CA      STANISLAUS  50 to 64 years    Male  Unknown
# 4    2021-08        TX       JEFFERSON  18 to 49 years    Male    White
# 5    2022-01        MI       WASHTENAW  50 to 64 years    Male    White
# 6    2022-01        GA         CHATHAM  18 to 49 years    Male    Black
# 7    2022-11        CA       SAN DIEGO       65+ years  Female    White
# 8    2022-11        MI          MONROE  50 to 64 years    Male    White
# 9    2022-03        CA  SAN BERNARDINO  18 to 49 years  Female       NA
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0              Probable Case    Symptomatic       No  Missing  Missing
# 1  Laboratory-confirmed case        Missing      Yes  Missing       No
# 2  Laboratory-confirmed case    Symptomatic  Missing  Missing  Unknown
# 3  Laboratory-confirmed case        Unknown  Missing  Missing  Missing
# 4  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 5              Probable Case    Symptomatic  Missing  Missing       NA
# 6  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 7  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 8  Laboratory-confirmed case    Symptomatic       No  Missing  Unknown
# 9  Laboratory-confirmed case        Unknown       No  Missing  Missing
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN

# %%
df["case_month"] = pd.to_datetime(df["case_month"], format='%Y-%m')
df.dtypes
# Out:
# case_month                  datetime64[ns]
# res_state                           object
# res_county                          object
# age_group                           object
# sex                                 object
# race                                object
# current_status                      object
# symptom_status                      object
# hosp_yn                             object
# icu_yn                              object
# death_yn                            object
# underlying_conditions_yn            object
# dtype: object

# %%
len(df)
# Out:
# 10000000

# %%
# What rows needed to be dropped through dropna()
print(f"Age Group column contains: {df['age_group'].unique()}")
print(f"Sex column contains: {df['sex'].unique()}")
print(f"Race column contains: {df['race'].unique()}")
# Out:
# Age Group column contains: ['0 - 17 years' '65+ years' '50 to 64 years' '18 to 49 years' 'Missing'
#  'NA']
# Sex column contains: ['Female' 'Male' 'NA' 'Unknown' 'Missing' 'Other']
# Race column contains: ['White' 'Unknown' 'Black' 'NA' 'Asian' 'Missing' 'Multiple/Other'
#  'American Indian/Alaska Native' 'Native Hawaiian/Other Pacific Islander']

# %%
df.head(10)
# Out:
#   case_month res_state      res_county       age_group     sex     race  \
# 0 2022-02-01        TX         HIDALGO    0 - 17 years  Female    White
# 1 2020-11-01        IN          PORTER       65+ years    Male    White
# 2 2021-02-01        OH         LICKING       65+ years  Female  Unknown
# 3 2021-03-01        CA      STANISLAUS  50 to 64 years    Male  Unknown
# 4 2021-08-01        TX       JEFFERSON  18 to 49 years    Male    White
# 5 2022-01-01        MI       WASHTENAW  50 to 64 years    Male    White
# 6 2022-01-01        GA         CHATHAM  18 to 49 years    Male    Black
# 7 2022-11-01        CA       SAN DIEGO       65+ years  Female    White
# 8 2022-11-01        MI          MONROE  50 to 64 years    Male    White
# 9 2022-03-01        CA  SAN BERNARDINO  18 to 49 years  Female       NA
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0              Probable Case    Symptomatic       No  Missing  Missing
# 1  Laboratory-confirmed case        Missing      Yes  Missing       No
# 2  Laboratory-confirmed case    Symptomatic  Missing  Missing  Unknown
# 3  Laboratory-confirmed case        Unknown  Missing  Missing  Missing
# 4  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 5              Probable Case    Symptomatic  Missing  Missing       NA
# 6  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 7  Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 8  Laboratory-confirmed case    Symptomatic       No  Missing  Unknown
# 9  Laboratory-confirmed case        Unknown       No  Missing  Missing
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN

# %%
age_df = df.copy()
age_df = age_df.drop(['sex', 'race'], axis=1)
age_df.head()
# Out:
#   case_month res_state  res_county       age_group             current_status  \
# 0 2022-02-01        TX     HIDALGO    0 - 17 years              Probable Case
# 1 2020-11-01        IN      PORTER       65+ years  Laboratory-confirmed case
# 2 2021-02-01        OH     LICKING       65+ years  Laboratory-confirmed case
# 3 2021-03-01        CA  STANISLAUS  50 to 64 years  Laboratory-confirmed case
# 4 2021-08-01        TX   JEFFERSON  18 to 49 years  Laboratory-confirmed case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0    Symptomatic       No  Missing  Missing                      NaN
# 1        Missing      Yes  Missing       No                      NaN
# 2    Symptomatic  Missing  Missing  Unknown                      NaN
# 3        Unknown  Missing  Missing  Missing                      NaN
# 4        Missing  Missing  Missing  Missing                      NaN

# %%
sex_df = df.copy()
sex_df = sex_df.drop(['age_group', 'race'], axis=1)
sex_df.head()
# Out:
#   case_month res_state  res_county     sex             current_status  \
# 0 2022-02-01        TX     HIDALGO  Female              Probable Case
# 1 2020-11-01        IN      PORTER    Male  Laboratory-confirmed case
# 2 2021-02-01        OH     LICKING  Female  Laboratory-confirmed case
# 3 2021-03-01        CA  STANISLAUS    Male  Laboratory-confirmed case
# 4 2021-08-01        TX   JEFFERSON    Male  Laboratory-confirmed case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0    Symptomatic       No  Missing  Missing                      NaN
# 1        Missing      Yes  Missing       No                      NaN
# 2    Symptomatic  Missing  Missing  Unknown                      NaN
# 3        Unknown  Missing  Missing  Missing                      NaN
# 4        Missing  Missing  Missing  Missing                      NaN

# %%
race_df = df.copy()
race_df = race_df.drop(['age_group', 'sex'], axis=1)
race_df.head()
# Out:
#   case_month res_state  res_county     race             current_status  \
# 0 2022-02-01        TX     HIDALGO    White              Probable Case
# 1 2020-11-01        IN      PORTER    White  Laboratory-confirmed case
# 2 2021-02-01        OH     LICKING  Unknown  Laboratory-confirmed case
# 3 2021-03-01        CA  STANISLAUS  Unknown  Laboratory-confirmed case
# 4 2021-08-01        TX   JEFFERSON    White  Laboratory-confirmed case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0    Symptomatic       No  Missing  Missing                      NaN
# 1        Missing      Yes  Missing       No                      NaN
# 2    Symptomatic  Missing  Missing  Unknown                      NaN
# 3        Unknown  Missing  Missing  Missing                      NaN
# 4        Missing  Missing  Missing  Missing                      NaN

# %%
age_df['age_group'].replace('Missing', pd.NA, inplace=True)
age_df.dropna(subset=['age_group'], inplace = True)
age_df = age_df[age_df['age_group'] != 'NA']
age_df.head(20)
# Out:
#    case_month res_state      res_county       age_group  \
# 0  2022-02-01        TX         HIDALGO    0 - 17 years
# 1  2020-11-01        IN          PORTER       65+ years
# 2  2021-02-01        OH         LICKING       65+ years
# 3  2021-03-01        CA      STANISLAUS  50 to 64 years
# 4  2021-08-01        TX       JEFFERSON  18 to 49 years
# 5  2022-01-01        MI       WASHTENAW  50 to 64 years
# 6  2022-01-01        GA         CHATHAM  18 to 49 years
# 7  2022-11-01        CA       SAN DIEGO       65+ years
# 8  2022-11-01        MI          MONROE  50 to 64 years
# 9  2022-03-01        CA  SAN BERNARDINO  18 to 49 years
# 10 2020-12-01        CA          SOLANO  50 to 64 years
# 11 2020-10-01        OR         JACKSON    0 - 17 years
# 12 2021-12-01        CA   SANTA BARBARA  18 to 49 years
# 13 2021-11-01        NH    HILLSBOROUGH  50 to 64 years
# 14 2022-01-01        NY           BRONX    0 - 17 years
# 15 2021-01-01        PA            YORK  18 to 49 years
# 16 2022-01-01        TN          BLOUNT  50 to 64 years
# 17 2021-01-01        PA       LANCASTER  50 to 64 years
# 18 2021-01-01        MI          MACOMB    0 - 17 years
# 19 2022-05-01        TN      WASHINGTON  50 to 64 years
#
#                current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0               Probable Case    Symptomatic       No  Missing  Missing
# 1   Laboratory-confirmed case        Missing      Yes  Missing       No
# 2   Laboratory-confirmed case    Symptomatic  Missing  Missing  Unknown
# 3   Laboratory-confirmed case        Unknown  Missing  Missing  Missing
# 4   Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 5               Probable Case    Symptomatic  Missing  Missing       NA
# 6   Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 7   Laboratory-confirmed case    Symptomatic       No  Missing  Missing
# 8   Laboratory-confirmed case    Symptomatic       No  Missing  Unknown
# 9   Laboratory-confirmed case        Unknown       No  Missing  Missing
# 10  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 11  Laboratory-confirmed case    Symptomatic       No  Missing       No
# 12  Laboratory-confirmed case    Symptomatic  Missing  Missing  Missing
# 13  Laboratory-confirmed case    Symptomatic       No       No  Unknown
# 14              Probable Case        Unknown  Missing  Missing  Missing
# 15  Laboratory-confirmed case    Symptomatic  Unknown  Unknown  Unknown
# 16  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 17  Laboratory-confirmed case    Symptomatic       No  Unknown  Unknown
# 18  Laboratory-confirmed case    Symptomatic  Missing  Missing       No
# 19  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#    underlying_conditions_yn
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      Yes
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN

# %%
print(f"Age Group column contains: {age_df['age_group'].unique()}")
print(f"Length of age_df: {len(age_df)}")
# Out:
# Age Group column contains: ['0 - 17 years' '65+ years' '50 to 64 years' '18 to 49 years']
# Length of age_df: 9858796

# %%
sex_df['sex'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
sex_df = sex_df[sex_df['sex'] != 'NA']
sex_df.dropna(subset=['sex'], inplace = True)
sex_df.head(20)
# Out:
#    case_month res_state      res_county     sex             current_status  \
# 0  2022-02-01        TX         HIDALGO  Female              Probable Case
# 1  2020-11-01        IN          PORTER    Male  Laboratory-confirmed case
# 2  2021-02-01        OH         LICKING  Female  Laboratory-confirmed case
# 3  2021-03-01        CA      STANISLAUS    Male  Laboratory-confirmed case
# 4  2021-08-01        TX       JEFFERSON    Male  Laboratory-confirmed case
# 5  2022-01-01        MI       WASHTENAW    Male              Probable Case
# 6  2022-01-01        GA         CHATHAM    Male  Laboratory-confirmed case
# 7  2022-11-01        CA       SAN DIEGO  Female  Laboratory-confirmed case
# 8  2022-11-01        MI          MONROE    Male  Laboratory-confirmed case
# 9  2022-03-01        CA  SAN BERNARDINO  Female  Laboratory-confirmed case
# 10 2020-12-01        CA          SOLANO  Female  Laboratory-confirmed case
# 11 2020-10-01        OR         JACKSON    Male  Laboratory-confirmed case
# 12 2021-12-01        CA   SANTA BARBARA    Male  Laboratory-confirmed case
# 13 2021-11-01        NH    HILLSBOROUGH  Female  Laboratory-confirmed case
# 14 2022-01-01        NY           BRONX    Male              Probable Case
# 15 2021-01-01        PA            YORK  Female  Laboratory-confirmed case
# 16 2022-01-01        TN          BLOUNT  Female  Laboratory-confirmed case
# 17 2021-01-01        PA       LANCASTER  Female  Laboratory-confirmed case
# 18 2021-01-01        MI          MACOMB    Male  Laboratory-confirmed case
# 19 2022-05-01        TN      WASHINGTON    Male  Laboratory-confirmed case
#
#    symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0     Symptomatic       No  Missing  Missing                      NaN
# 1         Missing      Yes  Missing       No                      NaN
# 2     Symptomatic  Missing  Missing  Unknown                      NaN
# 3         Unknown  Missing  Missing  Missing                      NaN
# 4         Missing  Missing  Missing  Missing                      NaN
# 5     Symptomatic  Missing  Missing       NA                      NaN
# 6     Symptomatic  Missing  Missing  Missing                      NaN
# 7     Symptomatic       No  Missing  Missing                      NaN
# 8     Symptomatic       No  Missing  Unknown                      NaN
# 9         Unknown       No  Missing  Missing                      NaN
# 10    Symptomatic  Missing  Missing  Missing                      NaN
# 11    Symptomatic       No  Missing       No                      NaN
# 12    Symptomatic  Missing  Missing  Missing                      NaN
# 13    Symptomatic       No       No  Unknown                      NaN
# 14        Unknown  Missing  Missing  Missing                      Yes
# 15    Symptomatic  Unknown  Unknown  Unknown                      NaN
# 16        Missing  Missing  Missing  Missing                      NaN
# 17    Symptomatic       No  Unknown  Unknown                      NaN
# 18    Symptomatic  Missing  Missing       No                      NaN
# 19        Missing  Missing  Missing  Missing                      NaN

# %%
print(f"Sex column contains: {sex_df['sex'].unique()}")
print(f"Length of sex_df: {len(sex_df)}")
# Out:
# Sex column contains: ['Female' 'Male' 'Other']
# Length of sex_df: 9788105

# %%
race_df['race'].replace({'Unknown': pd.NA, 'Missing': pd.NA}, inplace=True)
race_df = race_df[race_df['race'] != 'NA']
race_df.dropna(subset=['race'], inplace = True)
race_df.head(20)
# Out:
#    case_month res_state     res_county   race             current_status  \
# 0  2022-02-01        TX        HIDALGO  White              Probable Case
# 1  2020-11-01        IN         PORTER  White  Laboratory-confirmed case
# 4  2021-08-01        TX      JEFFERSON  White  Laboratory-confirmed case
# 5  2022-01-01        MI      WASHTENAW  White              Probable Case
# 6  2022-01-01        GA        CHATHAM  Black  Laboratory-confirmed case
# 7  2022-11-01        CA      SAN DIEGO  White  Laboratory-confirmed case
# 8  2022-11-01        MI         MONROE  White  Laboratory-confirmed case
# 12 2021-12-01        CA  SANTA BARBARA  Asian  Laboratory-confirmed case
# 13 2021-11-01        NH   HILLSBOROUGH  White  Laboratory-confirmed case
# 14 2022-01-01        NY          BRONX  Black              Probable Case
# 15 2021-01-01        PA           YORK  White  Laboratory-confirmed case
# 16 2022-01-01        TN         BLOUNT  White  Laboratory-confirmed case
# 17 2021-01-01        PA      LANCASTER  White  Laboratory-confirmed case
# 18 2021-01-01        MI         MACOMB  White  Laboratory-confirmed case
# 19 2022-05-01        TN     WASHINGTON  White  Laboratory-confirmed case
# 22 2022-01-01        NC          ROWAN  White  Laboratory-confirmed case
# 23 2021-11-01        NY       SARATOGA  White  Laboratory-confirmed case
# 24 2022-10-01        WI           ROCK  White  Laboratory-confirmed case
# 26 2021-09-01        ID         CANYON  White  Laboratory-confirmed case
# 27 2023-03-01        PA     LACKAWANNA  White  Laboratory-confirmed case
#
#    symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0     Symptomatic       No  Missing  Missing                      NaN
# 1         Missing      Yes  Missing       No                      NaN
# 4         Missing  Missing  Missing  Missing                      NaN
# 5     Symptomatic  Missing  Missing       NA                      NaN
# 6     Symptomatic  Missing  Missing  Missing                      NaN
# 7     Symptomatic       No  Missing  Missing                      NaN
# 8     Symptomatic       No  Missing  Unknown                      NaN
# 12    Symptomatic  Missing  Missing  Missing                      NaN
# 13    Symptomatic       No       No  Unknown                      NaN
# 14        Unknown  Missing  Missing  Missing                      Yes
# 15    Symptomatic  Unknown  Unknown  Unknown                      NaN
# 16        Missing  Missing  Missing  Missing                      NaN
# 17    Symptomatic       No  Unknown  Unknown                      NaN
# 18    Symptomatic  Missing  Missing       No                      NaN
# 19        Missing  Missing  Missing  Missing                      NaN
# 22        Unknown  Unknown  Unknown       No                      NaN
# 23    Symptomatic       No  Missing       No                      NaN
# 24    Symptomatic       No  Missing       No                      NaN
# 26        Missing  Missing  Missing  Missing                      NaN
# 27    Symptomatic  Unknown  Unknown  Unknown                      NaN

# %%
print(f"Race column contains: {race_df['race'].unique()}")
print(f"Length of sex_df: {len(race_df)}")
# Out:
# Race column contains: ['White' 'Black' 'Asian' 'Multiple/Other' 'American Indian/Alaska Native'
#  'Native Hawaiian/Other Pacific Islander']
# Length of sex_df: 6605369
